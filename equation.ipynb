# %%
"""
主要な方程式をまとめたプログラム

一覧
For_SDE
For_FPeq.
Re_SDE
Re_FPeq.
Re_Probability density function: ρ(x, t)

accurate_score: ∇xlogρ(x, t)
Hessian Matrix: ???


"""

# %%
class Equation():

  @staticmethod
  def for_sde():

    return 0

  @staticmethod
  def for_fpeq():

    return 0

  @staticmethod
  def re_sde():

    return 0
  @staticmethod
  def re_fpeq():

    return 0

  @staticmethod
  def prob_den_func():

    return 0

  @staticmethod
  def accurate_score():

    return 0

  @staticmethod
  def hessian_matrix():

    return 0
