# %%
"""
Cording Plan

・(400)枚 用意 ()変更可

主成分分析
・(400)枚で、分散共分散行列を算出
・分散共分散行列の固有値問題を解く。
・固有値分布を観察


変更可能箇所
・用意する枚数 (400)
・分岐点の箇所 (i=)

"""

# %%
#@title 指定枚数のロード
path = 0
par_middle = torch.load(path)

# %%
#@title 分散共分散行列の算出
torch.cov()

# %%
#@title 固有値問題
torch.eig()

# %%
#@title 固有値分布(各分岐点ごとに可視化)
